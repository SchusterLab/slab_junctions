# %%
# %run dose_chip_generator.py
# Out:
# ...
# DOSE CHIP GENERATOR
# ...
#
# Generating grids...
#   Adding dose test: Standard Junction Dose Test
#   Adding dose array: Standard Junction Geometry Sweep
#   Adding dose test: Standard Junction Dose Test
#   Adding dose array: Fluxonium Junction Geometry Sweep
#   Adding Manhattan dose test: Manhattan Junction Dose Test
#   Adding Manhattan width sweep: Manhattan Width Sweep
#
# Saving...
#   dose_chip_example.gds
#   dose_chip_example_dose_table.txt
#
# Done! Chip size: 7000x7000 um
# ...
